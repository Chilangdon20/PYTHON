# %% [markdown]
# # Funciones de distribucion de probabilidades.

# %% [markdown]
# ## Distribucion uniforme

# %%
#Numpy tiene una opcion para generar numeros aleatorios siguiendo la distribucion uniforme
import numpy as np
import matplotlib.pyplot as plt

# %%
a = 1
b = 200
n = 1000000
data = np.random.uniform(a,b,n)

# %%
# %matplotlib inline

# %%
plt.hist(data)
# Out:
# (array([100019.,  99937.,  99886.,  99883.,  99787., 100207.,  99690.,
#         100031.,  99825., 100735.]),
#  array([  1.00006829,  20.90006102,  40.80005375,  60.70004648,
#          80.60003921, 100.50003194, 120.40002466, 140.30001739,
#         160.20001012, 180.10000285, 199.99999558]),
#  <a list of 10 Patch objects>)

# %% [markdown]
# # Distribucion Normal.

# %% [markdown]
# La distribución normal es un modelo teórico capaz de aproximar satisfactoriamente el valor de una variable aleatoria continua a una situación ideal.
# En otras palabras, la distribución normal adapta una variable aleatoria continua a una función que depende de la media y la desviación típica. Es decir, la función y la variable aleatoria continua tendrán la misma representación pero con ligeras diferencias.

# %%
data = np.random.randn(1000000)

# %%
#Pintamos los datos con la funcion  plt.plot
x = range(1,1000001)
plt.plot(x,data)

# %%
plt.hist(data)
# Out:
# (array([2.50000e+01, 9.37000e+02, 1.46960e+04, 9.71310e+04, 2.81174e+05,
#         3.55498e+05, 1.97853e+05, 4.74520e+04, 5.01800e+03, 2.16000e+02]),
#  array([-4.97776231, -4.03597981, -3.0941973 , -2.1524148 , -1.2106323 ,
#         -0.2688498 ,  0.67293271,  1.61471521,  2.55649771,  3.49828021,
#          4.44006272]),
#  <a list of 10 Patch objects>)

# %%
#Funcion de distribucion acomulada
plt.plot(x,sorted(data))

# %%
mu = 5.5
sd = 2.5
data = mu + sd*np.random.randn(10000) #Z = (X -mu) / sd  -> N(0,1) TIPIFICAR
plt.hist(data)
# Out:
# (array([   9.,   62.,  394., 1230., 2502., 2847., 1996.,  780.,  157.,
#           23.]),
#  array([-4.37039975, -2.49745712, -0.62451449,  1.24842814,  3.12137077,
#          4.99431339,  6.86725602,  8.74019865, 10.61314128, 12.48608391,
#         14.35902654]),
#  <a list of 10 Patch objects>)

# %%
data = np.random.randn(200,4)
data.mean()
# Out:
# 0.0034354912888356817

# %%
plt.hist(data)
# Out:
# ([array([ 0.,  2., 11., 34., 55., 46., 33., 14.,  4.,  1.]),
#   array([ 0.,  1., 10., 38., 47., 50., 39., 11.,  3.,  1.]),
#   array([ 2.,  4., 11., 25., 44., 56., 39., 14.,  3.,  2.]),
#   array([ 0.,  1., 15., 31., 46., 37., 37., 19., 14.,  0.])],
#  array([-3.42936684, -2.76820242, -2.107038  , -1.44587358, -0.78470916,
#         -0.12354474,  0.53761968,  1.1987841 ,  1.85994852,  2.52111294,
#          3.18227736]),
#  <a list of 4 Lists of Patches objects>)

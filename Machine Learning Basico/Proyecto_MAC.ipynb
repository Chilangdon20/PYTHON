# %% [markdown]
# # INFORMACION GENREAL
#
# ---
#
#
#
# ## REDES GENERATIVAS ADVERSAS (GANs)
#
# Es un tipo de arquitectura donde tenmos 2 redes neuronales (el **Generador** y el ***Discriminador***) que aprenden a resover problemas diferntes.
#
# ##CONCEPTO BASICO DE LAS ***GANs***
# Dada una serie de muestras , el ***Generador ***intenta producir muestras que puedan ***engañar*** al ***Discriminador*** para que éste crea que son reales.
#
#  El ***Discriminador*** intenta resolver muestras reales (objetivo) a partir de muestras falsas (generadas).
#
# Usando este enfoque de entrenamiento o competición iterativa, eventualmente terminamos con un ***Generador*** que es realmente bueno generando muestras similares a las muestras reales y por lo tanto es capaz de engañar al ***Discriminador***.
#
# El Generador ha conseguido realizar una creación artificial (un texto, una imagen, un vídeo, un audio…) que es extremadamente similar al que pudiese ser el real. No es una copia, porque se ha creado algo nuevo, el Generador ha creado algo imitando un «estilo» real.
#
# #CONCEPTOS PREVIOS
#
# ##CONVULCION
#
# La convolución es una operación matemática, en la que una función se "aplica" de alguna manera a otra función. El resultado se puede entender como una "mezcla" de las dos funciones. La convolución se representa por un asterisco (*), que se puede confundir con el operador * que generalmente se utiliza para multiplicar en muchos lenguajes de programación.
#
# Pero ***¿cómo ayuda esto a detectar los objetos de una imagen?***
#
# Bueno, resulta que las convoluciones son realmente buenas para detectar estructuras sencillas de una imagen, y después para juntar esas sencillas funciones para construir funciones aún más complejas. En una red convolucional, este proceso ocurre sobre una serie de muchas capas, en la que cada una de ellas realiza una convolución sobre el resultado de la capa anterior.
#
# **¿PERO & SI PODEMOS INVERTIR ESTA RED CONVULACIONAL PARA QUE EL PROCESO SEA INVERSO?**
#
# #RED DECONVUCIONAL.
#
# ---
#
#
#
# Lo que hacemos ahora es que nuestra red neuronal tenga que predecir apartir de un vector numerico que especificamos, cuales son cada uno de los valores numericos que conforman los pixeles de la imagen.
#
# ***OBS*** : Cabe mencionar que cada vector que se le da como entrada es aleatorio , de tal forma que cada vez que se realice el proceso este generara una imagen apartir de  un vector aleatorio.
#
# ***OBSERVACION:***
# Pero y si nostros tenemos una imagen de diferentes frutas y queremos generar una fruta en espcifico ***(platano)*** como lo hacemos, pues podemos clasicicar las frutas en objetos donde el vector quedaria de la siguiente manera:
#
# 0 = Durazno
#
# 0 = Uvas
#
# 1 = Platano
#
# 0 = Sandia
#
# Podemos tomar este vector de etiquetas y lo suministramos como entrada de la red neuronal, i.e si antes teniamos un vector de numeros aleatorios lo que haremos sera introducir el vector etiqueta y el de numeros aleatorios y concatenarlos para ingresarlos a entrenamiento.
#
#
# ##FROM PIX TO PIX
#
#  **¿Que es pix2pix?**
#
#
#
# 1. Es la abreviatura de una implemntacion de traduccion generica de imagen a imagen , utilizando redes adversas condicionales.
#
# 2.  Dado un conjunto de entrenamiento que contiene pares de imagenes relacionadas ("A" & "B" ), un modelo pix2pix aprende como convertir una imagen del tipo "A" en una imagen del tipo "B" , o viceversa.
#
# # **Hourglass-like Model - (Arquitectura Reloj de arena)**
#
# El diseño del reloj de arena está motivado por la necesidad de capturar información en todas las escalas. Si bien la evidencia local es esencial para identificar características como caras y
#
#  La red debe tener algún mecanismo para procesar y consolidar de manera efectiva las características en todas las escalas. Algunos enfoques abordan esto con el uso de tuberías separadas que procesan la imagen de forma independiente en múltiples resoluciones y se combinan.
#
# El reloj de arena se configura de la siguiente manera: las capas de agrupación convolucional y máxima se utilizan para procesar características con una resolución muy baja.
#
# En cada paso de agrupación máxima, la red se ramifica y aplica más circunvoluciones en la resolución agrupada original. Después de alcanzar la resolución más baja, la red comienza la secuencia descendente de muestreo ascendente y combinación de características a través de escalas.
#
#   La topología del reloj de arena es simétrica, por lo que para cada capa presente en el camino hacia abajo hay una capa correspondiente que sube.
#
#
# # **U-Net**
#
# Como una red neuronal convolucional general enfoca su tarea en la clasificación de imágenes, donde la entrada es una imagen y la salida es una etiqueta.

# %%
###CONJUNTOS

# %%
c = set()

# %%
c.add(1)

# %%
c.add(2)

# %%
c
# Out:
# {1, 2}

# %%
c.add(1)

# %%
c
# Out:
# {1, 2}

# %%
c.add(0)

# %%
c
# Out:
# {0, 1, 2}

# %%
c.discard(0)

# %%
c
# Out:
# {1, 2}

# %%
c2 = c

# %%
c2.add(70)

# %%
c
c2
# Out:
# {1, 2, 70}

# %%
c
# Out:
# {1, 2, 70}

# %%
c2 = c.copy()

# %%
c2
# Out:
# {1, 2, 70}

# %%
c2.discard(70)

# %%
c2
# Out:
# {1, 2}

# %%
c
# Out:
# {1, 2, 70}

# %%
c2.clear()

# %%
c2
# Out:
# set()

# %%
c1 = {1,2,3}
c2 = {3,5,6}
c3 = {56,68,9}
c4 = {1,2,3,3,5,6}

# %%
c1.isdisjoint(c2)
# Out:
# False

# %%
c1.issubset(c4)
# Out:
# True

# %%
c4.issuperset(c1)
# Out:
# True

# %%
c1.union(c2) == c4
# Out:
# True

# %%
c1.union(c2)
# Out:
# {1, 2, 3, 5, 6}

# %%
c1
# Out:
# {1, 2, 3}

# %%
c2
# Out:
# {3, 5, 6}

# %%
c1.update(c2)

# %%
c1
# Out:
# {1, 2, 3, 5, 6}

# %%
c1.difference(c2)
# Out:
# {1, 2}

# %%
c1.difference_update(c2)

# %%
c1
# Out:
# {1, 2}

# %%
c1.symmetric_difference(c4)
# Out:
# {3, 5, 6}

# %% [markdown]
# # 1. Patrones de pensamiento locales y globales
#
# Si bien es posible que no seamos fanáticos de Twitter, tenemos que admitir que tiene una gran influencia en el mundo (quién no conoce los tweets de Trump).
#
# Los datos de Twitter no solo son oro en términos de información, sino que las tormentas de Twitter están disponibles para su análisis casi en tiempo real. Esto significa que podemos aprender sobre las grandes oleadas de pensamientos y estados de ánimo en todo el mundo a medida que surgen.
#
#
# Como cualquier lugar lleno de riquezas, Twitter tiene guardias de seguridad que nos impiden poner nuestras manos en los datos de inmediato ⛔️ Se necesitan algunos pasos de autenticación (realmente sencillos) para llamar a sus API para la recopilación de datos. Dado que nuestro objetivo de hoy es aprender a extraer conocimientos de los datos, ya hemos obtenido un pase verde de seguridad ✅ Nuestros datos están listos para su uso en la carpeta de conjuntos de datos; ¡podemos concentrarnos en la parte divertida! 🕵️‍♀️🌎.
#
# Twitter proporciona tendencias tanto globales como locales. Carguemos e inspeccionemos los datos de los temas que estaban de moda en todo el mundo (WW) y en los Estados Unidos (EE. UU.) En el momento de la consulta: instantánea de la respuesta JSON de la llamada a la API de lugar / tendencias GET de Twitter.
#
# ## Instrucciones:
#
# * Importemos el modulo `json`.
#
# * Abrir el archivo JSON usando el método `open()` con 'datasets / WWTrends.json' como parámetro de entrada -> llamemos al método `read()` en el archivo abierto para leer su contenido -> pasemos la cadena JSON de lectura a `json.loads( )` como parámetro de entrada para decodificarlo -> almacenar la salida decodificada en WW_trends.
#
#
# * Repetir los mismos pasos para 'datasets/USTrends.json' y almacenar la salida en US_trends.
#
# * Inspeionemos WW_trends y US_trends usando el método print ().

# %%
#Cargando módulo json

import json

# Carguemos los datos WW_trends y US_trends en las variables dadas respectivamente
WW_trends = json.loads(open('/content/WWTrends.json').read())
US_trends = json.loads(open('/content/USTrends.json').read())

# Inspeccionar datos imprimiendo las variables WW_trends y US_trends
print(WW_trends)
print(US_trends)
# Out:
# [{'trends': [{'name': '#BeratKandili', 'url': 'http://twitter.com/search?q=%23BeratKandili', 'promoted_content': None, 'query': '%23BeratKandili', 'tweet_volume': 46373}, {'name': '#GoodFriday', 'url': 'http://twitter.com/search?q=%23GoodFriday', 'promoted_content': None, 'query': '%23GoodFriday', 'tweet_volume': 81891}, {'name': '#WeLoveTheEarth', 'url': 'http://twitter.com/search?q=%23WeLoveTheEarth', 'promoted_content': None, 'query': '%23WeLoveTheEarth', 'tweet_volume': 159698}, {'name': '#195TLdenTTVerilir', 'url': 'http://twitter.com/search?q=%23195TLdenTTVerilir', 'promoted_content': None, 'query': '%23195TLdenTTVerilir', 'tweet_volume': None}, {'name': '#AFLNorthDons', 'url': 'http://twitter.com/search?q=%23AFLNorthDons', 'promoted_content': None, 'query': '%23AFLNorthDons', 'tweet_volume': None}, {'name': 'Shiv Sena', 'url': 'http://twitter.com/search?q=%22Shiv+Sena%22', 'promoted_content': None, 'query': '%22Shiv+Sena%22', 'tweet_volume': None}, {'name': 'Lyra McKee', 'url'
# ...

# %% [markdown]
# ## Embelleciendo nuestros datos.
#
#
# ¡Nuestros datos eran difíciles de leer! Afortunadamente, podemos recurrir al método `json.dumps()` para formatearlo como una bonita cadena JSON.
#
# ### INSTRUCCIONES:
#
# * Pasar el objeto `WW_trends` al método json.dumps (), con una sangría de parámetro de entrada adicional establecida en 1. imprimir la salida.
#
# * Hacer lo mismo para `US_trends`.
#
#
# Recordemos que `json.dumps()` formatea los datos como una cadena JSON. Si pasamos 'indent' al método (un entero positivo), entonces todos los elementos de la matriz JSON se imprimen con ese nivel de sangría. Esto facilita la lectura de los resultados, con una buena impresión.

# %%
# Imprimiendo los resultados. Primero la WW y luego las tendencias estadounidenses.

print("WW trends:")
print(json.dumps(WW_trends,indent=1))

print("\n", "US trends:")
print(json.dumps(US_trends,indent=1))
# Out:
# WW trends:
# [
#  {
#   "trends": [
#    {
#     "name": "#BeratKandili",
#     "url": "http://twitter.com/search?q=%23BeratKandili",
#     "promoted_content": null,
#     "query": "%23BeratKandili",
#     "tweet_volume": 46373
#    },
#    {
#     "name": "#GoodFriday",
#     "url": "http://twitter.com/search?q=%23GoodFriday",
#     "promoted_content": null,
#     "query": "%23GoodFriday",
#     "tweet_volume": 81891
#    },
#    {
#     "name": "#WeLoveTheEarth",
#     "url": "http://twitter.com/search?q=%23WeLoveTheEarth",
#     "promoted_content": null,
#     "query": "%23WeLoveTheEarth",
#     "tweet_volume": 159698
#    },
#    {
#     "name": "#195TLdenTTVerilir",
#     "url": "http://twitter.com/search?q=%23195TLdenTTVerilir",
#     "promoted_content": null,
#     "query": "%23195TLdenTTVerilir",
#     "tweet_volume": null
#    },
#    {
#     "name": "#AFLNorthDons",
#     "url": "http://twitter.com/search?q=%23AFLNorthDons",
#     "promoted_content": null,
# ...

# %% [markdown]
# ## Encontrar tendencias comunes🕵️‍♀️
#
# De los resultados  impresos (salida de la tarea anterior), podemos observar que:
#
# * Tenemos una serie de objetos de tendencia que tienen:
#
# * El nombre del tema de tendencia.
# * El parámetro de consulta que se puede usar para buscar el tema en Twitter-Search.
# * Ea URL de búsqueda
# * El volumen de tweets de las últimas 24 horas, si está disponible. (Las tendencias se actualizan cada 5 minutos).
#
# En el momento de la consulta, #BeratKandili, #GoodFriday y #WeLoveTheEarth estaban en tendencia  en `WW.
#
# "tweet_volume"`esto  nos dice que **#WeLoveTheEarth** fue el más popular entre los tres.
#
# Los resultados no están ordenados por "tweet_volume".
#
# Hay algunas tendencias que son exclusivas de EE. UU.
#
# Es fácil hojear los dos conjuntos de tendencias y detectar tendencias comunes, pero no hagamos un trabajo "manual".
# Podemos usar alguna estructura de datos de conjuntos de Python para encontrar tendencias comunes; podemos iterar a través de los dos objetos de tendencias, convertir las listas de nombres en conjuntos y llamar al método de intersección para obtener los nombres comunes entre los dos conjuntos.
#
# ### INSTRUCCIONES:
#
# * Extraer el campo de nombre, `trend['name']`, de la lista de tendencias en `WW_trends` y `US_trends` usando la lista de comprensión (*). Puedes usar `WW_trends[0]['tendencias']` y `US_trends[0]['tendencias']` para que las iteraciones obtengan los nombres porque los objetos de tendencias son listas con un solo elemento.
#
# * Llamar al método `intersection()` en `world_trends` con `us_trends` como parámetro de entrada para obtener los elementos comunes entre los dos; almacenar la salida en la variable llamada `common_trends``.

# %%
# Extraer todos los nombres de tendencias WW de WW_trends
world_trends = set([trend['name']
                    for trend in WW_trends[0]['trends']])

# Extraer todos los nombres de tendencias de EE. UU. De US_trends
us_trends = set([trend['name']
                 for trend in US_trends[0]['trends']]) 

# Obtener la intersección de los dos conjuntos de tendencias
common_trends = world_trends.intersection(us_trends)

# Inspeccionanado nuestros datos
print(world_trends,"\n")
# Out:
# {'#BeratKandili', 'Shiv Sena', 'Lyra McKee', 'Lil Dicky', '#IndonesianElectionHeroes', '#NikahUmurBerapa', '#HayırlıKandiller', '免許返納', '#Karfreitag', '#HayırlıCumalar', '#WeLoveTheEarth', '東京・池袋衝突事故', '#DuyguAsena', 'Priyanka Chaturvedi', '#TheJudasInMyLife', '#ShivSena', '#195TLdenTTVerilir', 'Berat Kandilimiz', '#ProtestoEdiyorum', '#AFLNorthDons', '브이알', '刀ステ', 'グレア', '#KpuJanganCurang', '#Jersey', '重体の女性と女児', '#GoodFriday', '#BLACKPINKxCorden', '#CHIvLIO', '#DragRace', '#ViernesSanto', 'Derry', 'örgütdeğil arkadaşgrubu', '#19aprile', 'Hemant Karkare', '池袋の事故', '#HardikPatel', '#JunquerasACN', 'Derrick White', '十二国記', '#HanumanJayanti', '歩行者', 'プリウス', '#DinahJane1', '高齢者', '#اغلاق_BBM', '#Ontas', '#NRLBulldogsSouths', '#ConCalmaRemix', '#يوم_الجمعه'}

# %%
print(us_trends, "\n")
# Out:
# {'Kazuo Koike', '#RPDR', '#CUZILOVEYOU', '#WGAMIX', 'Lyra McKee', 'Lil Dicky', 'Lone Wolf and Cub', 'Seth Abramson', 'Servais', '#MyDrunkUncleSays', '#GossipShouldBe', '#TheLegendOfVoxMachina', '#WeLoveTheEarth', '"Earth"', '#Earth', '#DontChangeOutNow', '#LilDicky', '#WorldofWarcraftMains', '#WhatStopsYouFromGoingHome', '#TimeToImpeach', '#GSWvsLAC', '#MakeAMovieSensual', 'Shy Glizzy', '#AFLNorthDons', '#CriticalRoleSpoilers', 'David Fletcher', 'Silky', 'Tomas Hertl', 'WE LOVE THE EARTH', '#HustleAndSoul', '#BLACKPINKxCorden', '#WeirdDateStories', 'Gallant', '#rupaulsdragrace', '#fridaymotivation', '#DragRace', 'Yvie', 'Derry', 'Oshie', 'Derrick White', '#StarTrekDiscovery', '#MyInnerDemonSaid', 'George Conway', 'Mike Anderson', '#DinahJane1', '#FridayFeeling', '#NRLBulldogsSouths', '#ConCalmaRemix', 'Game 6', 'Kevin Durant'}

# %%
print (len(common_trends), "tendencias en común:", common_trends)
# Out:
# 11 tendencias en común: {'#DragRace', '#WeLoveTheEarth', 'Derry', 'Derrick White', 'Lyra McKee', 'Lil Dicky', '#BLACKPINKxCorden', '#DinahJane1', '#NRLBulldogsSouths', '#ConCalmaRemix', '#AFLNorthDons'}

# %% [markdown]
# #  Explorando la tendencia actual🕵️‍♀️
#
# Desde la intersección (último resultado) podemos ver que, de los dos conjuntos de tendencias (cada uno de tamaño 50), tenemos 11 temas en común.
#
# En particular, hay una tendencia común que suena muy interesante: #WeLoveTheEarth - ¡Qué bueno ver que los Twitteratis están hablando unánimemente sobre amar a la Madre Tierra! 💚
#
# ### Nota: Podríamos haber tenido ninguna superposición o una superposición mucho mayor; Cuando hicimos la consulta para obtener las tendencias, la gente en los EE. UU. podría haber estado entusiasmada con los temas que solo les eran relevantes.
#
# Hemos encontrado una tendencia candente, #WeLoveTheEarth. ¡Ahora veamos qué historia nos está gritando contar!
# Si consultamos la API de búsqueda de Twitter con este hashtag como parámetro de consulta, obtenemos tweets reales relacionados con él. Tenemos la respuesta de la API de búsqueda almacenada en la carpeta de conjuntos de datos como 'WeLoveTheEarth.json'. Así que carguemos este conjunto de datos y profundicemos en esta tendencia.
#
# ### INSTRUCCIONES:
#
# * Al igual que en la Tarea 1, usar el método `open()` con `'datasets / WeLoveTheEarth.json'` como parámetro de entrada para abrir el archivo -> llame al método read () en el archivo abierto para leer su contenido -> pase la cadena JSON de lectura a el método json.loads () como parámetro de entrada para decodificarlo -> almacenar la salida decodificada en tweets.

# %%
# Cargamos los datos
tweets = json.loads(open('/content/WeLoveTheEarth.json').read())

# Inspeccionamos algunos tweets
tweets[0:2]
# Out:
# [{'contributors': None,
#   'coordinates': None,
#   'created_at': 'Fri Apr 19 08:46:48 +0000 2019',
#   'entities': {'hashtags': [{'indices': [30, 45], 'text': 'WeLoveTheEarth'}],
#    'symbols': [],
#    'urls': [{'display_url': 'youtu.be/pvuN_WvF1to',
#      'expanded_url': 'https://youtu.be/pvuN_WvF1to',
#      'indices': [46, 69],
#      'url': 'https://t.co/L22XsoT5P1'}],
#    'user_mentions': [{'id': 1209516660,
#      'id_str': '1209516660',
#      'indices': [3, 18],
#      'name': 'LD',
#      'screen_name': 'lildickytweets'}]},
#   'favorite_count': 0,
#   'favorited': False,
#   'geo': None,
#   'id': 1119160405270523904,
#   'id_str': '1119160405270523904',
#   'in_reply_to_screen_name': None,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'is_quote_status': False,
#   'lang': 'en',
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'place': None,
# ...

# %% [markdown]
# # Cavando más profundo🕵️‍♀️
#
# La impresión de los dos primeros elementos del tweet nos hace darnos cuenta de que hay mucho más en un tweet de lo que normalmente consideramos un tweet: ¡hay mucho más que un texto breve!
#
# Pero bueno, ¡no nos dejemos abrumar por toda la información en un objeto de tweet! Centrémonos en algunos campos interesantes y veamos si podemos encontrar información oculta allí.
#
# ### INSTRUCCIONES:
#
# * Para cada tweet en el objeto `tweets`, extraer su campo de texto, `tweet['text']`, usando la comprensión de lista. Almacenar todos los textos de salida en una lista denominada `texts`.
#
#
# * Para cada tweet en tweets, crear un bucle interno para iterar a través de las menciones de usuario, `tweet ['entities']['user_mentions']`. De cada mención_usuario extraiga su campo de nombre de pantalla, user_mention['screen_name']. Almacenar la salida en `names`.
#
#
# * Para cada tweet en tweets, cree un bucle interno para iterar a través de hashtags, tweet ['entidades'] ['hashtags']. De cada hashtag extraiga su campo de texto, hashtag ['texto']. Almacena la salida en hashtags

# %%
# Extraer el texto de todos los tweets del objeto tweet
texts = [tweet['text'] 
                 for tweet in tweets ]

# Extraer los nombres de pantalla de los usuarios que tuitean sobre #WeLoveTheEarth
names = [user_mention['screen_name'] 
                 for tweet in tweets
                     for user_mention in tweet['entities']['user_mentions']]

# Extraer todos los hashtags que se utilizan al hablar de este tema.
hashtags = [hashtag['text'] 
             for tweet in tweets
                 for hashtag in tweet['entities']['hashtags']]

# %%
# Inspeccionamos los resultados
print (json.dumps(texts[0:10], indent=1),"\n")
# Out:
# [
#  "RT @lildickytweets: \ud83c\udf0e out now #WeLoveTheEarth https://t.co/L22XsoT5P1",
#  "\ud83d\udc9a\ud83c\udf0e\ud83d\udc9a  #WeLoveTheEarth \ud83d\udc47\ud83c\udffc",
#  "RT @cabeyoomoon: Ta piosenka to bop,  wpada w ucho  i dochody z niej id\u0105 na dobry cel,  warto s\u0142ucha\u0107 w k\u00f3\u0142ko i w k\u00f3\u0142ko gdziekolwiek si\u0119 ty\u2026",
#  "#WeLoveTheEarth \nCzemu ja si\u0119 pop\u0142aka\u0142am",
#  "RT @Spotify: This is epic. @lildickytweets got @justinbieber, @arianagrande, @halsey, @sanbenito, @edsheeran, @SnoopDogg, @ShawnMendes, @Kr\u2026",
#  "RT @biebercentineo: Justin : are we gonna die? \nLil dicky: you know bieber we might die \n\nBTCH IM CRYING #EARTH #WeLoveTheEarth #WELOVEEART\u2026",
#  "RT @dreamsiinflate: #WeLoveTheEarth \u201ci am a fat fucking pig\u201d okay brendon urie https://t.co/FdJmq31xZc",
# ...

# %%
print (json.dumps(names[0:10], indent=1),"\n")
# Out:
# [
#  "lildickytweets",
#  "cabeyoomoon",
#  "Spotify",
#  "lildickytweets",
#  "justinbieber",
#  "ArianaGrande",
#  "halsey",
#  "sanbenito",
#  "edsheeran",
#  "SnoopDogg"
# ]

# %%
print (json.dumps(hashtags[0:10], indent=1),"\n")
# Out:
# [
#  "WeLoveTheEarth",
#  "WeLoveTheEarth",
#  "WeLoveTheEarth",
#  "EARTH",
#  "WeLoveTheEarth",
#  "WeLoveTheEarth",
#  "WeLoveTheEarth",
#  "EdSheeranTheKoala",
#  "WeLoveTheEarth",
#  "WeLoveTheEarth"
# ]

# %% [markdown]
# # Análisis de frecuencia🕵️‍♀️
#
# Solo de los primeros resultados de la última extracción, podemos deducir que:
#
# * Estamos hablando de una canción sobre amar la Tierra.
# * Muchos grandes artistas son las fuerzas detrás de esta ola de Twitter, especialmente Lil Dicky.
# * Ed Sheeran era un lindo koala en la canción - ¡hashtag "EdSheeranTheKoala"! 🐨
# * La observación de los primeros 10 elementos de los campos interesantes nos dio una idea de los datos. Ahora podemos echar un vistazo más de cerca haciendo un ejercicio simple, pero muy útil: calcular las distribuciones de frecuencia. Comenzar de manera simple con frecuencias es generalmente un buen enfoque; ayuda a obtener ideas sobre cómo seguir adelante.
#
# ### INSTRUCCIONES:
#
# * Importe el módulo Counter de colecciones.
#
# * Llamar al método Counter () con el elemento del bucle for como parámetro de entrada. (Esto le permite realizar un seguimiento de cuántas veces se agregan los mismos valores).

# %%
# importando counter
from collections import Counter

# Contando ocurrencias / obteniendo la distribución de frecuencia de todos los nombres y hashtags
for item in [names, hashtags]:
    c = Counter(item)    
    # Inspeccionando los 10 elementos más comunes en c
    print (c.most_common(10), "\n")
# Out:
# [('lildickytweets', 102), ('LeoDiCaprio', 44), ('ShawnMendes', 33), ('halsey', 31), ('ArianaGrande', 30), ('justinbieber', 29), ('Spotify', 26), ('edsheeran', 26), ('sanbenito', 25), ('SnoopDogg', 25)]
#
# [('WeLoveTheEarth', 313), ('4future', 12), ('19aprile', 12), ('EARTH', 11), ('fridaysforfuture', 10), ('EarthMusicVideo', 3), ('ConCalmaRemix', 3), ('Earth', 3), ('aliens', 2), ('AvengersEndgame', 2)]

# %% [markdown]
# # Actividad en torno a la tendencia🕵️‍♀️
#
# Basándonos en las últimas distribuciones de frecuencia, podemos aumentar nuestras deducciones:
#
# * Podemos decir con más seguridad que este fue un video musical sobre la Tierra (hashtag 'EarthMusicVideo') de Lil Dicky.
#
#
# * DiCaprio no es un artista musical, pero también estuvo involucrado (Leo es un ambientalista, así que no es una sorpresa ver su nombre aparecer aquí).
#
#
# * También podemos decir que el video fue lanzado un viernes; muy probablemente el 19 de abril.
#
# * Hemos podido extraer muchísimos conocimientos. Bastante poderoso, ¿no?
#
# <p> Analicemos más los datos para encontrar patrones en la actividad alrededor de los tweets:
#
# * <b> ¿todos los retweets ocurrieron alrededor de un tweet en particular? </b> <br> </p>
#
# * <p> Si se ha retuiteado un tweet, el campo <i> 'retweeted_status' </i> brinda muchos detalles interesantes sobre el tweet original y su autor. </p>
#
# <p> Podemos medir la popularidad de un tweet analizando la <b><i>retweet<em>count</em></i> </b> y <b> <i> favoritecount </i> </ b > campos. Pero extraigamos también el número de seguidores del tweet: tenemos muchas celebridades en la imagen, así que...
#
# <b> ¿podemos saber si su defensa de #WeLoveTheEarth influyó en una proporción significativa de sus seguidores? </b> </ p >
# <hr>
# <p><i> <b> Nota </b>: Retweet_count nos da el número total de veces que se retuiteó el tweet original. Debería ser el mismo tanto en el tweet original como en todos los retweets siguientes. Jugar con algunos tweets de muestra y la documentación oficial son la forma de familiarizarse con los campos de mnay. </i> </p>
#
# ### INSTRUCCIONES:
#
# * Obtener `'retweet_count'`, `'retweeted_status\favorite_count'`,`'retweeted_status\user\followers_count'`,`'retweeted_status\user\screen_name'`, & `'text'`  para cada tweet del bucle for dado, respetando este orden.

# %%
# Extrayendo información útil de retweets
retweets = [
             (tweet['retweet_count'], 
              tweet['retweeted_status']['favorite_count'],
              tweet['retweeted_status']['user']['followers_count'],
              tweet['retweeted_status']['user']['screen_name'],
              tweet['text']) 
            
            for tweet in tweets 
                if 'retweeted_status' in tweet
           ]

# %% [markdown]
# # Una DataFrame habla  mas que 1000 palabras
#
# Manipulemos los datos más y visualícelos de una manera mejor y más rica: "¡el aspecto importa!"
#
# ### INSTRUCCIONES:
#
# * Crearemos un DataFrame usando el constructor `pd.DataFrame()` pasando el objeto retweets como entrada. También configuremos las columnas de parámetros de entrada adicionales a `['Retweets', 'Favorites', 'Followers', 'ScreenName', 'Text'].
#
# * Llamar a `groupby()` en el DataFrame resultante con ['ScreenName', 'Text', 'Followers'] como parámetro de entrada.
#
# * Luego llamar a sum () en los resultados del groupby para calcular un agregado de las columnas numéricas.
#
# * Finalmente, llamar a `sort_values()` con los parámetros de entrada configurados en ['Followers'] y ascendiendo a False para ordenar la tabla disminuyendo el número de seguidores.

# %%
# Importando modulos
import matplotlib.pyplot as plt
import pandas as pd

# Visualizando los datos en un formato mas bonito
df = pd.DataFrame(
    retweets, 
    columns=['Retweets','Favorites','Followers','ScreenName','Text']).groupby(
    ['ScreenName','Text','Followers']).sum().sort_values(by=['Followers'], ascending=False)

df.style.background_gradient()
# Out:
# <style  type="text/css" >
#     #T_e3b08fc0_e314_11ea_bf21_0242ac1c0002row0_col0 {
#             background-color:  #fdf5fa;
#             color:  #000000;
#         }    #T_e3b08fc0_e314_11ea_bf21_0242ac1c0002row0_col1 {
#             background-color:  #fbf4f9;
#             color:  #000000;
#         }    #T_e3b08fc0_e314_11ea_bf21_0242ac1c0002row1_col0 {
#             background-color:  #fdf5fa;
#             color:  #000000;
#         }    #T_e3b08fc0_e314_11ea_bf21_0242ac1c0002row1_col1 {
#             background-color:  #fbf4f9;
#             color:  #000000;
#         }    #T_e3b08fc0_e314_11ea_bf21_0242ac1c0002row2_col0 {
#             background-color:  #fdf5fa;
#             color:  #000000;
#         }    #T_e3b08fc0_e314_11ea_bf21_0242ac1c0002row2_col1 {
#             background-color:  #fbf4f9;
#             color:  #000000;
#         }    #T_e3b08fc0_e314_11ea_bf21_0242ac1c0002row3_col0 {
#             background-color:  #dedcec;
#             color:  #000000;
# ...

# %% [markdown]
# # Analizando idiomas usados 🕵️‍♀️
#
# Nuestro dataframe nos dice que:
#
# * Los seguidores de Lil Dicky fueron los que más reaccionaron al 42,4% de sus seguidores le gustó su primer tweet.
#
# Incluso si celebridades como Katy Perry y Ellen tienen una gran cantidad de seguidores en Twitter, sus seguidores apenas reaccionaron, por ejemplo, solo al 0.0098% de los seguidores de Katy le gustó su tweet.
#
# * Si bien Leo obtuvo la mayor cantidad de me gusta y retweets en términos de conteos, su primer tweet solo le gustó al 2.19% de sus seguidores.
#
# Las grandes diferencias en las reacciones podrían explicarse por el hecho de que este era el video musical de Lil Dicky. Leo todavía consiguió más tracción que Katy o Ellen porque desempeñó un papel importante en esta iniciativa.
#
# ¿Podemos encontrar algunos patrones más interesantes en los datos? A partir del texto de los tweets, pudimos detectar diferentes idiomas, así que creemos una distribución de frecuencia para los idiomas.

# %%
# Extraer el idioma de cada tweet y agregarlo a la lista de idiomas
tweets_languages = []
for tweet in tweets:
        tweets_languages.append(tweet['lang'])

# Trazando la distribución de idiomas
import seaborn as sns
# %matplotlib inline
sns.set()
_ = plt.hist(tweets_languages,color='#319F9B')
_ = plt.xlabel("Idiomas")
_ = plt.ylabel("No Tweets")
_ = plt.title("Distribución de lenguajes respecto a tweets")

plt.show()

# %% [markdown]
# # Pensamientos finales🕵️‍♀️
#
# El último histograma nos dice que:
#
# * La mayoría de los tweets estaban en inglés.
# * Polacos, italianos y españoles fueron los siguientes subcampeones.
# * Hubo muchos tweets con un lenguaje ajeno a Twitter (lang = 'und').
#
# ¿Por qué es útil este tipo de información? Porque puede permitirnos comprender la "categoría" de personas interesadas en este tema (agrupación).
